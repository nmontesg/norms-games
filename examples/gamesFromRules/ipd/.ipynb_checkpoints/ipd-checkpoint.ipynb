# %% [markdown]
# This notebook demostrates the creation of some Extensive Form Games (EFGs), all of them versions of the Iterated Prisoner's Dilemma game, from the Prolog description of an action situation according to the syntax of *if-then-where* rules.

# %%
import os
import sys
ngames_path = os.path.abspath(os.path.join(os.getcwd(), '../../..', 'ngames'))
sys.path.append(ngames_path)

# %%
from extensivegames import plot_game
from build import build_full_game
from equilibrium import minimize_incentives, subgame_perfect_equilibrium

# %% [markdown]
# # Default rules
#
# Agent are allowed to cooperate and defect whenever.

# %%
game_ipd_default = build_full_game('.', 'ipd', threshold=0)

# %%
def set_utility(game):
    r"""Set the utility of the game at the terminal nodes.
    
    Set the utility at the terminal nodes to the payoff the agents have
    received. Other possibilities are possible (e.g. consider equality).
    """
    for n in game.game_tree.terminal_nodes:
        node_utility = {}
        facts = game.node_info[n]
        for f in facts:
            predicate = f.split('(')[0]
            args = f.split('(')[1][:-1].split(', ')
            if predicate == 'payoff':
                node_utility[args[0]] = float(args[1])
        game.set_utility(n, node_utility)
        
set_utility(game_ipd_default)

# %%
position_colors =  {'alice':'cyan', 'bob':'red'}

# default keywords for rendering the figure
my_fig_kwargs = dict(figsize=(25,10), frameon=False, tight_layout=True)
my_node_kwargs = dict(font_size=10, node_size=500, edgecolors='k',
                      linewidths=1.5)
my_edge_kwargs = dict(arrowsize=15, width=2.5)
my_edge_labels_kwargs = dict(font_size=14)
my_patch_kwargs = dict(linewidth=1.5)
my_legend_kwargs = dict(fontsize=16, loc='upper right', edgecolor='white')
my_utility_label_kwargs = dict(horizontalalignment='center', fontsize=10)
my_info_sets_kwargs = dict(linestyle='--', linewidth=2)

fig = plot_game(game_ipd_default, 
                position_colors,
                fig_kwargs=my_fig_kwargs,
                node_kwargs=my_node_kwargs,
                edge_kwargs=my_edge_kwargs,
                edge_labels_kwargs=my_edge_labels_kwargs,
                patch_kwargs=my_patch_kwargs,
                legend_kwargs=my_legend_kwargs,
                utility_label_kwargs=my_utility_label_kwargs,
                utility_label_shift=0.08,
                info_sets_kwargs=my_info_sets_kwargs)

# %%
# fig.savefig('ipd_default.png', bbox_inches='tight', dpi=500)

# %%
subgame_mixed_strat, back_utilities, incentives = subgame_perfect_equilibrium(game_ipd_default, minimize_incentives)

for node, mixed_strategy_profile in subgame_mixed_strat.items():
    print("At node {}: f(s)={:.3f}".format(node, incentives[node]))
    for player, player_strat in mixed_strategy_profile.items():
        print("{}: {}".format(player, player_strat))
    print()
# Out:
# At node 10: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 11: f(s)=0.000
# alice: {'cooperate': 1.3766765505351941e-14, 'defect': 0.9999999999999862}
# bob: {'cooperate': 2.220446049250313e-15, 'defect': 0.9999999999999981}
#
# At node 12: f(s)=0.000
# alice: {'cooperate': 1.3022916078853086e-13, 'defect': 0.9999999999998697}
# bob: {'cooperate': 9.46465128492946e-15, 'defect': 0.9999999999999908}
#
# At node 13: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 16: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 17: f(s)=0.000
# alice: {'cooperate': 7.438494264988549e-15, 'defect': 0.9999999999999926}
# bob: {'cooperate': 2.5413005033669833e-13, 'defect': 0.999999999999746}
#
# At node 18: f(s)=0.000
# alice: {'cooperate': 2.653433028854124e-14, 'defect': 0.9999999999999736}
# bob: {'cooperate': 1.5720758028692217e-13, 'defect': 0.9999999999998428}
#
# At node 19: f(s)=0.000
# alice: {'cooperate': 2.148281552649678e-14, 'defect': 0.9999999999999785}
# bob: {'cooperate': 4.0190073491430667e-14, 'defect': 0.9999999999999599}
#
# At node 24: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 2.919886554764162e-14, 'defect': 0.9999999999999708}
#
# At node 25: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 22: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 23: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 28: f(s)=0.000
# alice: {'cooperate': 1.0591527654923993e-13, 'defect': 0.9999999999998939}
# bob: {'cooperate': 7.238654120556021e-14, 'defect': 0.9999999999999278}
#
# At node 29: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 30: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 31: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 4: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 5: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 6: f(s)=0.000
# alice: {'cooperate': 4.1466829969749597e-14, 'defect': 0.9999999999999586}
# bob: {'cooperate': 3.236300116782331e-14, 'defect': 0.9999999999999678}
#
# At node 7: f(s)=0.000
# alice: {'cooperate': 1.73749903353837e-13, 'defect': 0.9999999999998263}
# bob: {'cooperate': 1.6064927166326015e-13, 'defect': 0.9999999999998398}
#
# At node 1: f(s)=0.000
# alice: {'cooperate': 5.417888360170764e-14, 'defect': 0.9999999999999458}
# bob: {'cooperate': 1.5265566588595902e-14, 'defect': 0.9999999999999852}

# %% [markdown]
# # Limit consecutive defections
#
# Agent are not allowed to defect more than twice in a row.

# %%
game_ipd_limit_defections = build_full_game('.', 'ipd', threshold=1)
set_utility(game_ipd_limit_defections)

# %%
fig = plot_game(game_ipd_limit_defections, 
                position_colors,
                fig_kwargs=my_fig_kwargs,
                node_kwargs=my_node_kwargs,
                edge_kwargs=my_edge_kwargs,
                edge_labels_kwargs=my_edge_labels_kwargs,
                patch_kwargs=my_patch_kwargs,
                legend_kwargs=my_legend_kwargs,
                utility_label_kwargs=my_utility_label_kwargs,
                utility_label_shift=0.08,
                info_sets_kwargs=my_info_sets_kwargs)

# %%
# fig.savefig('ipd_limit_defections.png', bbox_inches='tight', dpi=500)

# %%
n = 5
for _ in range(10):
    subgame_mixed_strat, back_utilities, _ = subgame_perfect_equilibrium(game_ipd_limit_defections, minimize_incentives)
    print(subgame_mixed_strat[n])
    print(back_utilities[n])
    print()
# Out:
# {'alice': {'cooperate': 0.0, 'defect': 1.0}, 'bob': {'cooperate': 0.7777777777777778, 'defect': 0.2222222222222222}}
# {'alice': 12.000000000000131, 'bob': 12.000000000000004}
#
# {'alice': {'cooperate': 0.0, 'defect': 1.0}, 'bob': {'cooperate': 1.0, 'defect': 0.0}}
# {'alice': 12.000000000003244, 'bob': 11.999999999999417}
#
# {'alice': {'cooperate': 1.5554224574998443e-13, 'defect': 0.9999999999998445}, 'bob': {'cooperate': 0.25000000000001454, 'defect': 0.7499999999999859}}
# {'alice': 11.999999999999652, 'bob': 12.000000000001217}
#
# {'alice': {'cooperate': 0.0, 'defect': 1.0}, 'bob': {'cooperate': 1.0, 'defect': 5.551115123125783e-17}}
# {'alice': 11.999999999999986, 'bob': 12.000000000000028}
#
# {'alice': {'cooperate': 8.748557434046234e-14, 'defect': 0.9999999999999125}, 'bob': {'cooperate': 0.8571428571428591, 'defect': 0.14285714285714107}}
# {'alice': 11.999999999999751, 'bob': 12.000000000000574}
#
# {'alice': {'cooperate': 2.1960211427085596e-13, 'defect': 0.9999999999997805}, 'bob': {'cooperate': 0.33333300550779804, 'defect': 0.6666669944922023}}
# {'alice': 11.99999999999923, 'bob': 12.000000000001558}
#
# {'alice': {'cooperate': 1.5554224574998443e-13, 'defect': 0.9999999999998445}, 'bob': {'cooperate': 0.6666666666666812, 'defect': 0.3333333333333192}}
# {'alice': 11.999999999999536, 'bob': 12.000000000000943}
#
# {'alice': {'cooperate': 6.106226635438361e-16, 'defect': 0.9999999999999994}, 'bob': {'cooperate': 1.0547118733938987e-15, 'defect': 0.9999999999999991}}
# {'alice': 12.0, 'bob': 12.000000000000005}
#
# {'alice': {'cooperate': 4.551914400963142e-15, 'defect': 0.9999999999999953}, 'bob': {'cooperate': 0.3846153846153865, 'defect': 0.6153846153846136}}
# {'alice': 11.999999999999986, 'bob': 12.000000000000028}
#
# {'alice': {'cooperate': 2.1649348980190553e-15, 'defect': 0.9999999999999978}, 'bob': {'cooperate': 0.5000000000000073, 'defect': 0.4999999999999929}}
# {'alice': 12.000000000000153, 'bob': 11.999999999999941}

# %% [markdown]
# # Penalize mutual defection
#
# If both agents defect, the outcome is *as if* one agent had defected on the other. The agent that acts as the defector is selected randomly.
#
# The generated game for this configuration is limited to 2 rounds.

# %%
game_ipd_ban_mutual_defect = build_full_game('.', 'ipd', threshold=2)
set_utility(game_ipd_ban_mutual_defect)

# %%
fig = plot_game(game_ipd_ban_mutual_defect, 
                position_colors,
                fig_kwargs=my_fig_kwargs,
                node_kwargs=my_node_kwargs,
                edge_kwargs=my_edge_kwargs,
                edge_labels_kwargs=my_edge_labels_kwargs,
                patch_kwargs=my_patch_kwargs,
                legend_kwargs=my_legend_kwargs,
                utility_label_kwargs=my_utility_label_kwargs,
                utility_label_shift=0.08,
                info_sets_kwargs=my_info_sets_kwargs)

# %%
# fig.savefig('ipd_ban_mutual_defect.png', bbox_inches='tight', dpi=500)

# %%
subgame_mixed_strat, back_utilities, incentives = subgame_perfect_equilibrium(game_ipd_ban_mutual_defect, minimize_incentives)

for node, mixed_strategy_profile in subgame_mixed_strat.items():
    print("At node {}: f(s)={:.3f}".format(node, incentives[node]))
    for player, player_strat in mixed_strategy_profile.items():
        print("{}: {}".format(player, player_strat))
    print()
# Out:
# At node 12: f(s)=0.000
# alice: {'cooperate': 6.017408793468348e-14, 'defect': 0.9999999999999398}
# bob: {'cooperate': 1.532107773982716e-14, 'defect': 0.9999999999999849}
#
# At node 13: f(s)=0.000
# alice: {'cooperate': 2.3037127760971998e-14, 'defect': 0.9999999999999769}
# bob: {'cooperate': 1.6042722705833512e-14, 'defect': 0.9999999999999841}
#
# At node 14: f(s)=0.000
# alice: {'cooperate': 9.070522111187529e-14, 'defect': 0.9999999999999093}
# bob: {'cooperate': 5.492273302820649e-13, 'defect': 0.9999999999994509}
#
# At node 16: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 17: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 20: f(s)=0.000
# alice: {'cooperate': 5.162537064506978e-15, 'defect': 0.9999999999999949}
# bob: {'cooperate': 1.887379141862766e-15, 'defect': 0.9999999999999983}
#
# At node 21: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 1.1102230246251565e-15, 'defect': 0.9999999999999991}
#
# At node 22: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 24: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 25: f(s)=0.000
# alice: {'cooperate': 1.2567724638756772e-13, 'defect': 0.9999999999998745}
# bob: {'cooperate': 1.2245759961615477e-13, 'defect': 0.9999999999998777}
#
# At node 28: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 29: f(s)=0.000
# alice: {'cooperate': 4.39648317751562e-14, 'defect': 0.999999999999956}
# bob: {'cooperate': 4.9182879990894435e-14, 'defect': 0.9999999999999512}
#
# At node 30: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 32: f(s)=0.000
# alice: {'cooperate': 1.4988010832439613e-15, 'defect': 0.9999999999999984}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 33: f(s)=0.000
# alice: {'cooperate': 5.651035195342047e-14, 'defect': 0.9999999999999435}
# bob: {'cooperate': 6.183942247162122e-14, 'defect': 0.9999999999999383}
#
# At node 36: f(s)=0.000
# alice: {'cooperate': 6.722400414105323e-14, 'defect': 0.9999999999999327}
# bob: {'cooperate': 2.927658115936538e-13, 'defect': 0.9999999999997073}
#
# At node 37: f(s)=0.000
# alice: {'cooperate': 1.156852391659413e-13, 'defect': 0.9999999999998843}
# bob: {'cooperate': 1.1124434706744069e-13, 'defect': 0.9999999999998889}
#
# At node 38: f(s)=0.000
# alice: {'cooperate': 1.0702549957386509e-13, 'defect': 0.9999999999998931}
# bob: {'cooperate': 1.3555823130673161e-13, 'defect': 0.9999999999998648}
#
# At node 40: f(s)=0.000
# alice: {'cooperate': 1.7486012637846216e-15, 'defect': 0.9999999999999982}
# bob: {'cooperate': 2.758904216193514e-14, 'defect': 0.9999999999999725}
#
# At node 41: f(s)=0.000
# alice: {'cooperate': 7.271960811294775e-15, 'defect': 0.9999999999999927}
# bob: {'cooperate': 2.8754776337791554e-14, 'defect': 0.9999999999999714}
#
# At node 44: f(s)=0.000
# alice: {'cooperate': 9.986456106503283e-14, 'defect': 0.9999999999999002}
# bob: {'cooperate': 1.1257661469699087e-13, 'defect': 0.9999999999998878}
#
# At node 45: f(s)=0.000
# alice: {'cooperate': 1.5265566588595902e-16, 'defect': 0.9999999999999999}
# bob: {'cooperate': 2.914335439641036e-16, 'defect': 0.9999999999999998}
#
# At node 46: f(s)=0.000
# alice: {'cooperate': 6.162848009694244e-13, 'defect': 0.9999999999993836}
# bob: {'cooperate': 0.0, 'defect': 1.0}
#
# At node 48: f(s)=0.000
# alice: {'cooperate': 1.5565326805244695e-13, 'defect': 0.9999999999998443}
# bob: {'cooperate': 1.3639089857520048e-13, 'defect': 0.9999999999998637}
#
# At node 49: f(s)=0.000
# alice: {'cooperate': 2.6700863742235015e-13, 'defect': 0.9999999999997329}
# bob: {'cooperate': 2.8554936193359026e-13, 'defect': 0.9999999999997148}
#
# At node 4: f(s)=0.000
# alice: {'cooperate': 3.1363800445660672e-15, 'defect': 0.9999999999999969}
# bob: {'cooperate': 1.4377388168895777e-14, 'defect': 0.9999999999999857}
#
# At node 5: f(s)=0.000
# alice: {'cooperate': 5.828670879282072e-16, 'defect': 0.9999999999999994}
# bob: {'cooperate': 2.6650903706126883e-13, 'defect': 0.9999999999997335}
#
# At node 6: f(s)=0.000
# alice: {'cooperate': 6.48925357893404e-14, 'defect': 0.9999999999999352}
# bob: {'cooperate': 6.70019595361282e-14, 'defect': 0.9999999999999332}
#
# At node 8: f(s)=0.000
# alice: {'cooperate': 1.4788170688007085e-13, 'defect': 0.9999999999998521}
# bob: {'cooperate': 3.838596107641479e-14, 'defect': 0.9999999999999618}
#
# At node 9: f(s)=0.000
# alice: {'cooperate': 1.8762769116165146e-14, 'defect': 0.9999999999999812}
# bob: {'cooperate': 1.6986412276764895e-14, 'defect': 0.9999999999999832}
#
# At node 1: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
