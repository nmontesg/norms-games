# %% [markdown]
# This notebook demostrates the creation of some Extensive Form Games (EFGs), all of them versions of the Iterated Prisoner's Dilemma game, from the Prolog description of an action situation according to the syntax of *if-then-where* rules.

# %%
from ngames.evaluation.extensivegames import ExtensiveFormGame, plot_game
from ngames.evaluation.build import build_game_from_rule_combination
from ngames.evaluation.equilibrium import minimize_incentives, \
    subgame_perfect_equilibrium, outcome_probability

# %% [markdown]
# # Default rules
#
# Agent are allowed to cooperate and defect whenever.

# %%
game_ipd_default = build_game_from_rule_combination('.', 'ipd',
                                            {'n1': -1, 'n2': -1, 'n3': -1})

position_colors = {'alice': 'cyan', 'bob': 'red'}

# default keywords for rendering the figure
my_fig_kwargs = dict(figsize=(25, 10), frameon=False, tight_layout=True)
my_node_kwargs = dict(font_size=10, node_size=500, edgecolors='k',
                      linewidths=1.5)
my_edge_kwargs = dict(arrowsize=15, width=2.5)
my_edge_labels_kwargs = dict(font_size=14)
my_patch_kwargs = dict(linewidth=1.5)
my_legend_kwargs = dict(fontsize=16, loc='upper right', edgecolor='white')
my_utility_label_kwargs = dict(horizontalalignment='center', fontsize=10,
                               weight='bold')
my_info_sets_kwargs = dict(linestyle='--', linewidth=2)

fig = plot_game(game_ipd_default, 
                position_colors,
                fig_kwargs=my_fig_kwargs,
                node_kwargs=my_node_kwargs,
                edge_kwargs=my_edge_kwargs,
                edge_labels_kwargs=my_edge_labels_kwargs,
                patch_kwargs=my_patch_kwargs,
                legend_kwargs=my_legend_kwargs,
                utility_label_kwargs=my_utility_label_kwargs,
                decimals=0,
                utility_label_shift=0.08,
                info_sets_kwargs=my_info_sets_kwargs)

# %%
subgame_mixed_strat, back_utilities, incentives = \
    subgame_perfect_equilibrium(game_ipd_default, minimize_incentives)

for node, mixed_strategy_profile in subgame_mixed_strat.items():
    print("At node {}: f(s)={:.3f}".format(node, incentives[node]))
    for player, player_strat in mixed_strategy_profile.items():
        print("{}: {}".format(player, player_strat))
    print(back_utilities[node])
    print()
# Out:
# At node 10: f(s)=0.000
# alice: {'cooperate': 1.6653345369377348e-15, 'defect': 0.9999999999999984}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 14.999999999999996, 'bob': 15.000000000000012}
#
# At node 11: f(s)=0.000
# alice: {'cooperate': 4.218847493575595e-15, 'defect': 0.9999999999999958}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 8.999999999999988, 'bob': 18.00000000000003}
#
# At node 12: f(s)=0.000
# alice: {'cooperate': 3.1086244689504383e-15, 'defect': 0.9999999999999969}
# bob: {'cooperate': 1.1268763699945339e-14, 'defect': 0.9999999999999889}
# {'alice': 18.00000000000006, 'bob': 8.999999999999986}
#
# At node 13: f(s)=0.000
# alice: {'cooperate': 5.434541705540141e-14, 'defect': 0.9999999999999457}
# bob: {'cooperate': 4.446443213623752e-14, 'defect': 0.9999999999999557}
# {'alice': 12.000000000000107, 'bob': 12.000000000000195}
#
# At node 16: f(s)=0.000
# alice: {'cooperate': 4.218847493575595e-15, 'defect': 0.9999999999999958}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 8.999999999999988, 'bob': 18.00000000000003}
#
# At node 17: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 3.0, 'bob': 21.0}
#
# At node 18: f(s)=0.000
# alice: {'cooperate': 5.434541705540141e-14, 'defect': 0.9999999999999457}
# bob: {'cooperate': 4.446443213623752e-14, 'defect': 0.9999999999999557}
# {'alice': 12.000000000000107, 'bob': 12.000000000000195}
#
# At node 19: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 6.0, 'bob': 15.0}
#
# At node 22: f(s)=0.000
# alice: {'cooperate': 3.1086244689504383e-15, 'defect': 0.9999999999999969}
# bob: {'cooperate': 1.1268763699945339e-14, 'defect': 0.9999999999999889}
# {'alice': 18.00000000000006, 'bob': 8.999999999999986}
#
# At node 23: f(s)=0.000
# alice: {'cooperate': 5.434541705540141e-14, 'defect': 0.9999999999999457}
# bob: {'cooperate': 4.446443213623752e-14, 'defect': 0.9999999999999557}
# {'alice': 12.000000000000107, 'bob': 12.000000000000195}
#
# At node 24: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 21.0, 'bob': 3.0}
#
# At node 25: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 15.0, 'bob': 6.0}
#
# At node 28: f(s)=0.000
# alice: {'cooperate': 5.434541705540141e-14, 'defect': 0.9999999999999457}
# bob: {'cooperate': 4.446443213623752e-14, 'defect': 0.9999999999999557}
# {'alice': 12.000000000000107, 'bob': 12.000000000000195}
#
# At node 29: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 6.0, 'bob': 15.0}
#
# At node 30: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 15.0, 'bob': 6.0}
#
# At node 31: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 9.0, 'bob': 9.0}
#
# At node 4: f(s)=0.000
# alice: {'cooperate': 5.434541705540141e-14, 'defect': 0.9999999999999457}
# bob: {'cooperate': 4.446443213623752e-14, 'defect': 0.9999999999999557}
# {'alice': 12.000000000000213, 'bob': 12.00000000000039}
#
# At node 5: f(s)=0.000
# alice: {'cooperate': 8.604228440844963e-15, 'defect': 0.9999999999999913}
# bob: {'cooperate': 1.3766765505351941e-14, 'defect': 0.9999999999999865}
# {'alice': 6.000000000000058, 'bob': 15.000000000000012}
#
# At node 6: f(s)=0.000
# alice: {'cooperate': 4.207745263329343e-14, 'defect': 0.9999999999999579}
# bob: {'cooperate': 4.340972026284362e-14, 'defect': 0.9999999999999568}
# {'alice': 15.000000000000137, 'bob': 6.0000000000001235}
#
# At node 7: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 9.0, 'bob': 9.0}
#
# At node 1: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 9.0, 'bob': 9.0}

# %%
# compute the probability distribution over terminal nodes induced by the
# strategy
outcome_prob = {t: outcome_probability(game_ipd_default,
                                       subgame_mixed_strat, t)
                for t in game_ipd_default.game_tree.terminal_nodes}

for n, p in outcome_prob.items():
    if p > 1.E-5:
        print("{} -- {}".format(n, p))
        print(game_ipd_default.state_fluents[n])
        print()
# Out:
# 127 -- 1.0
# ['payoff(bob, 9.0)', 'payoff(alice, 9.0)', 'rounds(3.0)']

# %% [markdown]
# # Limit consecutive defections
#
# Agent are not allowed to defect more than twice in a row.

# %%
game_ipd_limit_defections = build_game_from_rule_combination('.',
                                        'ipd', {'n1': 1, 'n2': -1, 'n3': -1})

# %%
fig = plot_game(game_ipd_limit_defections, 
                position_colors,
                fig_kwargs=my_fig_kwargs,
                node_kwargs=my_node_kwargs,
                edge_kwargs=my_edge_kwargs,
                edge_labels_kwargs=my_edge_labels_kwargs,
                patch_kwargs=my_patch_kwargs,
                legend_kwargs=my_legend_kwargs,
                utility_label_kwargs=my_utility_label_kwargs,
                decimals=0,
                utility_label_shift=0.08,
                info_sets_kwargs=my_info_sets_kwargs)

# %%
subgame_mixed_strat, back_utilities, incentives = \
    subgame_perfect_equilibrium(game_ipd_limit_defections,
                                minimize_incentives)

for node, mixed_strategy_profile in subgame_mixed_strat.items():
    print("At node {}: f(s)={:.3f}".format(node, incentives[node]))
    for player, player_strat in mixed_strategy_profile.items():
        print("{}: {}".format(player, player_strat))
    print(back_utilities[node])
    print()
# Out:
# At node 10: f(s)=0.000
# alice: {'cooperate': 1.6653345369377348e-15, 'defect': 0.9999999999999984}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 14.999999999999996, 'bob': 15.000000000000012}
#
# At node 11: f(s)=0.000
# alice: {'cooperate': 4.218847493575595e-15, 'defect': 0.9999999999999958}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 8.999999999999988, 'bob': 18.00000000000003}
#
# At node 12: f(s)=0.000
# alice: {'cooperate': 3.1086244689504383e-15, 'defect': 0.9999999999999969}
# bob: {'cooperate': 1.1268763699945339e-14, 'defect': 0.9999999999999889}
# {'alice': 18.00000000000006, 'bob': 8.999999999999986}
#
# At node 13: f(s)=0.000
# alice: {'cooperate': 5.434541705540141e-14, 'defect': 0.9999999999999457}
# bob: {'cooperate': 4.446443213623752e-14, 'defect': 0.9999999999999557}
# {'alice': 12.000000000000107, 'bob': 12.000000000000195}
#
# At node 16: f(s)=0.000
# alice: {'cooperate': 4.218847493575595e-15, 'defect': 0.9999999999999958}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 8.999999999999988, 'bob': 18.00000000000003}
#
# At node 17: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 1.0}
# {'alice': 9.0, 'bob': 18.0}
#
# At node 18: f(s)=0.000
# alice: {'cooperate': 5.434541705540141e-14, 'defect': 0.9999999999999457}
# bob: {'cooperate': 4.446443213623752e-14, 'defect': 0.9999999999999557}
# {'alice': 12.000000000000107, 'bob': 12.000000000000195}
#
# At node 19: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 1.0}
# {'alice': 12.0, 'bob': 12.0}
#
# At node 22: f(s)=0.000
# alice: {'cooperate': 3.1086244689504383e-15, 'defect': 0.9999999999999969}
# bob: {'cooperate': 1.1268763699945339e-14, 'defect': 0.9999999999999889}
# {'alice': 18.00000000000006, 'bob': 8.999999999999986}
#
# At node 23: f(s)=0.000
# alice: {'cooperate': 5.434541705540141e-14, 'defect': 0.9999999999999457}
# bob: {'cooperate': 4.446443213623752e-14, 'defect': 0.9999999999999557}
# {'alice': 12.000000000000107, 'bob': 12.000000000000195}
#
# At node 24: f(s)=0.000
# alice: {'cooperate': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 18.0, 'bob': 9.0}
#
# At node 25: f(s)=0.000
# alice: {'cooperate': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 12.0, 'bob': 12.0}
#
# At node 28: f(s)=0.000
# alice: {'cooperate': 5.434541705540141e-14, 'defect': 0.9999999999999457}
# bob: {'cooperate': 4.446443213623752e-14, 'defect': 0.9999999999999557}
# {'alice': 12.000000000000107, 'bob': 12.000000000000195}
#
# At node 29: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 1.0}
# {'alice': 12.0, 'bob': 12.0}
#
# At node 30: f(s)=0.000
# alice: {'cooperate': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 12.0, 'bob': 12.0}
#
# At node 31: f(s)=0.000
# alice: {'cooperate': 1.0}
# bob: {'cooperate': 1.0}
# {'alice': 12.0, 'bob': 12.0}
#
# At node 4: f(s)=0.000
# alice: {'cooperate': 5.434541705540141e-14, 'defect': 0.9999999999999457}
# bob: {'cooperate': 4.446443213623752e-14, 'defect': 0.9999999999999557}
# {'alice': 12.000000000000213, 'bob': 12.00000000000039}
#
# At node 5: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.5000000000000002, 'defect': 0.5}
# {'alice': 12.000000000000057, 'bob': 12.0000000000001}
#
# At node 6: f(s)=0.000
# alice: {'cooperate': 0.49999999999998956, 'defect': 0.5000000000000104}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 12.000000000000053, 'bob': 12.000000000000098}
#
# At node 7: f(s)=0.000
# alice: {'cooperate': 0.5, 'defect': 0.5}
# bob: {'cooperate': 0.5, 'defect': 0.5}
# {'alice': 12.000000000000027, 'bob': 12.00000000000005}
#
# At node 1: f(s)=0.000
# alice: {'cooperate': 0.5, 'defect': 0.5}
# bob: {'cooperate': 0.5, 'defect': 0.5}
# {'alice': 12.000000000000089, 'bob': 12.00000000000016}

# %%
# compute the probability distribution over terminal nodes induced by the
# strategy
outcome_prob = {t: outcome_probability(game_ipd_limit_defections,
                                       subgame_mixed_strat, t)
                for t in game_ipd_limit_defections.game_tree.terminal_nodes}

for n, p in outcome_prob.items():
    if p > 1.E-5:
        print("{} -- {}".format(n, p))
        print(game_ipd_limit_defections.state_fluents[n])
        print()
# Out:
# 55 -- 0.2499999999999507
# ['consecutiveDefections(bob, 2.0)', 'consecutiveDefections(alice, 2.0)', 'payoff(bob, 12.0)', 'payoff(alice, 12.0)', 'rounds(3.0)']
#
# 71 -- 0.12499999999998773
# ['consecutiveDefections(bob, 1.0)', 'consecutiveDefections(alice, 2.0)', 'payoff(bob, 12.0)', 'payoff(alice, 12.0)', 'rounds(3.0)']
#
# 75 -- 0.125
# ['consecutiveDefections(bob, 0)', 'consecutiveDefections(alice, 2.0)', 'payoff(alice, 12.0)', 'payoff(bob, 12.0)', 'rounds(3.0)']
#
# 87 -- 0.12499999999998507
# ['consecutiveDefections(bob, 2.0)', 'consecutiveDefections(alice, 1.0)', 'payoff(bob, 12.0)', 'payoff(alice, 12.0)', 'rounds(3.0)']
#
# 93 -- 0.1250000000000026
# ['consecutiveDefections(alice, 0)', 'consecutiveDefections(bob, 2.0)', 'payoff(bob, 12.0)', 'payoff(alice, 12.0)', 'rounds(3.0)']
#
# 99 -- 0.06249999999999384
# ['consecutiveDefections(bob, 1.0)', 'consecutiveDefections(alice, 1.0)', 'payoff(bob, 12.0)', 'payoff(alice, 12.0)', 'rounds(3.0)']
#
# 103 -- 0.0625
# ['consecutiveDefections(bob, 0)', 'consecutiveDefections(alice, 1.0)', 'payoff(alice, 12.0)', 'payoff(bob, 12.0)', 'rounds(3.0)']
#
# 106 -- 0.0625
# ['consecutiveDefections(alice, 0)', 'consecutiveDefections(bob, 1.0)', 'payoff(bob, 12.0)', 'payoff(alice, 12.0)', 'rounds(3.0)']
#
# 108 -- 0.0625
# ['consecutiveDefections(bob, 0)', 'consecutiveDefections(alice, 0)', 'payoff(bob, 12.0)', 'payoff(alice, 12.0)', 'rounds(3.0)']

# %% [markdown]
# # Penalize mutual defection
#
# If both agents defect, the outcome is *as if* one agent had defected on the other. The agent that acts as the defector is selected randomly.
#
# The generated game for this configuration is limited to 2 rounds.

# %%
game_ipd_ban_mutual_defect = build_game_from_rule_combination('.',
                                        'ipd', {'n1':-1, 'n2':1, 'n3':-1})

# %%
fig = plot_game(game_ipd_ban_mutual_defect, 
                position_colors,
                fig_kwargs=my_fig_kwargs,
                node_kwargs=my_node_kwargs,
                edge_kwargs=my_edge_kwargs,
                edge_labels_kwargs=my_edge_labels_kwargs,
                patch_kwargs=my_patch_kwargs,
                legend_kwargs=my_legend_kwargs,
                utility_label_kwargs=my_utility_label_kwargs,
                decimals=0,
                utility_label_shift=0.08,
                info_sets_kwargs=my_info_sets_kwargs)

# %%
subgame_mixed_strat, back_utilities, incentives = \
    subgame_perfect_equilibrium(game_ipd_ban_mutual_defect,
                                minimize_incentives)

for node, mixed_strategy_profile in subgame_mixed_strat.items():
    print("At node {}: f(s)={:.3f}".format(node, incentives[node]))
    for player, player_strat in mixed_strategy_profile.items():
        print("{}: {}".format(player, player_strat))
    print(back_utilities[node])
    print()
# Out:
# At node 12: f(s)=0.000
# alice: {'cooperate': 3.680389326632394e-14, 'defect': 0.9999999999999633}
# bob: {'cooperate': 2.90878432451791e-14, 'defect': 0.9999999999999711}
# {'alice': 16.499999999999968, 'bob': 16.50000000000004}
#
# At node 13: f(s)=0.000
# alice: {'cooperate': 1.1401990462900358e-13, 'defect': 0.999999999999886}
# bob: {'cooperate': 1.010858063921205e-13, 'defect': 0.9999999999998992}
# {'alice': 10.499999999999945, 'bob': 19.500000000000064}
#
# At node 14: f(s)=0.000
# alice: {'cooperate': 1.6930901125533637e-14, 'defect': 0.9999999999999831}
# bob: {'cooperate': 1.3433698597964394e-14, 'defect': 0.9999999999999867}
# {'alice': 19.499999999999986, 'bob': 10.500000000000018}
#
# At node 16: f(s)=0.000
# alice: {'cooperate': 1.6930901125533637e-14, 'defect': 0.9999999999999831}
# bob: {'cooperate': 1.3433698597964394e-14, 'defect': 0.9999999999999867}
# {'alice': 19.499999999999986, 'bob': 10.500000000000018}
#
# At node 17: f(s)=0.000
# alice: {'cooperate': 1.1401990462900358e-13, 'defect': 0.999999999999886}
# bob: {'cooperate': 1.010858063921205e-13, 'defect': 0.9999999999998992}
# {'alice': 10.499999999999945, 'bob': 19.500000000000064}
#
# At node 20: f(s)=0.000
# alice: {'cooperate': 1.1401990462900358e-13, 'defect': 0.999999999999886}
# bob: {'cooperate': 1.010858063921205e-13, 'defect': 0.9999999999998992}
# {'alice': 10.499999999999945, 'bob': 19.500000000000064}
#
# At node 21: f(s)=0.000
# alice: {'cooperate': 3.9246383920499284e-14, 'defect': 0.9999999999999608}
# bob: {'cooperate': 3.375077994860476e-14, 'defect': 0.9999999999999665}
# {'alice': 4.499999999999977, 'bob': 22.50000000000003}
#
# At node 22: f(s)=0.000
# alice: {'cooperate': 8.598677325721837e-14, 'defect': 0.999999999999914}
# bob: {'cooperate': 7.760458942129844e-14, 'defect': 0.9999999999999226}
# {'alice': 13.499999999999964, 'bob': 13.500000000000039}
#
# At node 24: f(s)=0.000
# alice: {'cooperate': 8.598677325721837e-14, 'defect': 0.999999999999914}
# bob: {'cooperate': 7.760458942129844e-14, 'defect': 0.9999999999999226}
# {'alice': 13.499999999999964, 'bob': 13.500000000000039}
#
# At node 25: f(s)=0.000
# alice: {'cooperate': 3.9246383920499284e-14, 'defect': 0.9999999999999608}
# bob: {'cooperate': 3.375077994860476e-14, 'defect': 0.9999999999999665}
# {'alice': 4.499999999999977, 'bob': 22.50000000000003}
#
# At node 28: f(s)=0.000
# alice: {'cooperate': 1.6930901125533637e-14, 'defect': 0.9999999999999831}
# bob: {'cooperate': 1.3433698597964394e-14, 'defect': 0.9999999999999867}
# {'alice': 19.499999999999986, 'bob': 10.500000000000018}
#
# At node 29: f(s)=0.000
# alice: {'cooperate': 8.598677325721837e-14, 'defect': 0.999999999999914}
# bob: {'cooperate': 7.760458942129844e-14, 'defect': 0.9999999999999226}
# {'alice': 13.499999999999964, 'bob': 13.500000000000039}
#
# At node 30: f(s)=0.000
# alice: {'cooperate': 8.271161533457416e-15, 'defect': 0.9999999999999917}
# bob: {'cooperate': 1.4932499681208355e-14, 'defect': 0.9999999999999852}
# {'alice': 22.500000000000032, 'bob': 4.499999999999971}
#
# At node 32: f(s)=0.000
# alice: {'cooperate': 8.271161533457416e-15, 'defect': 0.9999999999999917}
# bob: {'cooperate': 1.4932499681208355e-14, 'defect': 0.9999999999999852}
# {'alice': 22.500000000000032, 'bob': 4.499999999999971}
#
# At node 33: f(s)=0.000
# alice: {'cooperate': 8.598677325721837e-14, 'defect': 0.999999999999914}
# bob: {'cooperate': 7.760458942129844e-14, 'defect': 0.9999999999999226}
# {'alice': 13.499999999999964, 'bob': 13.500000000000039}
#
# At node 36: f(s)=0.000
# alice: {'cooperate': 1.6930901125533637e-14, 'defect': 0.9999999999999831}
# bob: {'cooperate': 1.3433698597964394e-14, 'defect': 0.9999999999999867}
# {'alice': 19.499999999999986, 'bob': 10.500000000000018}
#
# At node 37: f(s)=0.000
# alice: {'cooperate': 8.598677325721837e-14, 'defect': 0.999999999999914}
# bob: {'cooperate': 7.760458942129844e-14, 'defect': 0.9999999999999226}
# {'alice': 13.499999999999964, 'bob': 13.500000000000039}
#
# At node 38: f(s)=0.000
# alice: {'cooperate': 8.271161533457416e-15, 'defect': 0.9999999999999917}
# bob: {'cooperate': 1.4932499681208355e-14, 'defect': 0.9999999999999852}
# {'alice': 22.500000000000032, 'bob': 4.499999999999971}
#
# At node 40: f(s)=0.000
# alice: {'cooperate': 8.271161533457416e-15, 'defect': 0.9999999999999917}
# bob: {'cooperate': 1.4932499681208355e-14, 'defect': 0.9999999999999852}
# {'alice': 22.500000000000032, 'bob': 4.499999999999971}
#
# At node 41: f(s)=0.000
# alice: {'cooperate': 8.598677325721837e-14, 'defect': 0.999999999999914}
# bob: {'cooperate': 7.760458942129844e-14, 'defect': 0.9999999999999226}
# {'alice': 13.499999999999964, 'bob': 13.500000000000039}
#
# At node 44: f(s)=0.000
# alice: {'cooperate': 1.1401990462900358e-13, 'defect': 0.999999999999886}
# bob: {'cooperate': 1.010858063921205e-13, 'defect': 0.9999999999998992}
# {'alice': 10.499999999999945, 'bob': 19.500000000000064}
#
# At node 45: f(s)=0.000
# alice: {'cooperate': 3.9246383920499284e-14, 'defect': 0.9999999999999608}
# bob: {'cooperate': 3.375077994860476e-14, 'defect': 0.9999999999999665}
# {'alice': 4.499999999999977, 'bob': 22.50000000000003}
#
# At node 46: f(s)=0.000
# alice: {'cooperate': 8.598677325721837e-14, 'defect': 0.999999999999914}
# bob: {'cooperate': 7.760458942129844e-14, 'defect': 0.9999999999999226}
# {'alice': 13.499999999999964, 'bob': 13.500000000000039}
#
# At node 48: f(s)=0.000
# alice: {'cooperate': 8.598677325721837e-14, 'defect': 0.999999999999914}
# bob: {'cooperate': 7.760458942129844e-14, 'defect': 0.9999999999999226}
# {'alice': 13.499999999999964, 'bob': 13.500000000000039}
#
# At node 49: f(s)=0.000
# alice: {'cooperate': 3.9246383920499284e-14, 'defect': 0.9999999999999608}
# bob: {'cooperate': 3.375077994860476e-14, 'defect': 0.9999999999999665}
# {'alice': 4.499999999999977, 'bob': 22.50000000000003}
#
# At node 4: f(s)=0.000
# alice: {'cooperate': 2.6201263381153694e-14, 'defect': 0.9999999999999738}
# bob: {'cooperate': 2.5424107263916085e-14, 'defect': 0.9999999999999747}
# {'alice': 14.999999999999963, 'bob': 15.000000000000046}
#
# At node 5: f(s)=0.000
# alice: {'cooperate': 1.5343282200319663e-13, 'defect': 0.9999999999998466}
# bob: {'cooperate': 1.2734258092450546e-13, 'defect': 0.9999999999998728}
# {'alice': 8.999999999999854, 'bob': 18.000000000000156}
#
# At node 6: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 18.0, 'bob': 9.000000000000005}
#
# At node 8: f(s)=0.000
# alice: {'cooperate': 0.0, 'defect': 1.0}
# bob: {'cooperate': 0.0, 'defect': 1.0}
# {'alice': 18.0, 'bob': 9.000000000000005}
#
# At node 9: f(s)=0.000
# alice: {'cooperate': 1.5343282200319663e-13, 'defect': 0.9999999999998466}
# bob: {'cooperate': 1.2734258092450546e-13, 'defect': 0.9999999999998728}
# {'alice': 8.999999999999854, 'bob': 18.000000000000156}
#
# At node 1: f(s)=0.000
# alice: {'cooperate': 1.1046719095020308e-14, 'defect': 0.9999999999999889}
# bob: {'cooperate': 5.10702591327572e-15, 'defect': 0.9999999999999951}
# {'alice': 13.499999999999904, 'bob': 13.50000000000011}

# %%
# compute the probability distribution over terminal nodes induced by the
# strategy
outcome_prob = {t: outcome_probability(game_ipd_ban_mutual_defect,
                                       subgame_mixed_strat, t)
                for t in game_ipd_ban_mutual_defect.game_tree.terminal_nodes}

for n, p in outcome_prob.items():
    if p > 1.E-5:
        print("{} -- {}".format(n, p))
        print(game_ipd_ban_mutual_defect.state_fluents[n])
        print()
# Out:
# 200 -- 0.12499999999999512
# ['payoff(alice, 27.0)', 'payoff(bob, 0.0)', 'rounds(3.0)']
#
# 201 -- 0.12499999999999512
# ['payoff(alice, 18.0)', 'payoff(bob, 9.0)', 'rounds(3.0)']
#
# 208 -- 0.12499999999997757
# ['payoff(alice, 18.0)', 'payoff(bob, 9.0)', 'rounds(3.0)']
#
# 209 -- 0.12499999999997757
# ['payoff(alice, 9.0)', 'payoff(bob, 18.0)', 'rounds(3.0)']
#
# 240 -- 0.12499999999994249
# ['payoff(alice, 18.0)', 'payoff(bob, 9.0)', 'rounds(3.0)']
#
# 241 -- 0.12499999999994249
# ['payoff(alice, 9.0)', 'payoff(bob, 18.0)', 'rounds(3.0)']
#
# 248 -- 0.12499999999995383
# ['payoff(alice, 9.0)', 'payoff(bob, 18.0)', 'rounds(3.0)']
#
# 249 -- 0.12499999999995383
# ['payoff(alice, 0.0)', 'payoff(bob, 27.0)', 'rounds(3.0)']

# %% [markdown]
# # Allow perfectly enforceable agreements
#
# Agents can communicate prior to start playing, and settle on what action to take for the rest of the game.

# %%
game_ipd_negotiate = build_game_from_rule_combination('.', 'ipd',
                                            {'n1': -1, 'n2': -1, 'n3': 1})

fig = plot_game(game_ipd_negotiate, 
                position_colors,
                fig_kwargs=my_fig_kwargs,
                node_kwargs=my_node_kwargs,
                edge_kwargs=my_edge_kwargs,
                edge_labels_kwargs=my_edge_labels_kwargs,
                patch_kwargs=my_patch_kwargs,
                legend_kwargs=my_legend_kwargs,
                utility_label_kwargs=my_utility_label_kwargs,
                decimals=0,
                utility_label_shift=0.095,
                info_sets_kwargs=my_info_sets_kwargs)

# %%
subgame_mixed_strat, back_utilities, incentives = \
    subgame_perfect_equilibrium(game_ipd_negotiate,
                                minimize_incentives)

# compute the probability distribution over terminal nodes induced by the
# strategy
outcome_prob = {t: outcome_probability(game_ipd_negotiate,
                                       subgame_mixed_strat, t)
                for t in game_ipd_negotiate.game_tree.terminal_nodes}

for n, p in outcome_prob.items():
    if p > 1.E-5:
        print("{} -- {}".format(n, p))
        print(game_ipd_negotiate.state_fluents[n])
        print()
# Out:
# 151 -- 0.9999999969452724
# ['negotiation_off', 'deal(cooperate, cooperate)', 'payoff(bob, 18.0)', 'payoff(alice, 18.0)', 'rounds(3.0)']
